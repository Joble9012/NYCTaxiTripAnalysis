# %%
# !pip install pyspark

# !pip install pandas

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv('/Users/joblethomas/Desktop/Learning/L1.csv')
# Out:
#     Name  Age
# 0   John   23
# 1  Smith   36
# 2  Chris   18

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/23 21:19:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://macbookpro.fios-router.home:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('/Users/joblethomas/Desktop/Learning/L1.csv')

# %%
df_pyspark.show()
# Out:
# +-----+---+
# |  _c0|_c1|
# +-----+---+
# | Name|Age|
# | John| 23|
# |Smith| 36|
# |Chris| 18|
# +-----+---+

# %%
df_pyspark = spark.read.option('Header','true').csv('/Users/joblethomas/Desktop/Learning/L1.csv')

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='John', Age='23'),
#  Row(Name='Smith', Age='36'),
#  Row(Name='Chris', Age='18')]

# %%
df_pyspark.printSchema()
# Out:
# <bound method DataFrame.printSchema of DataFrame[Name: string, Age: string]>
